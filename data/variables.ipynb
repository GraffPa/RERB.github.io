# %% [markdown]
# # Creation de la base finale pour JS

# %% [markdown]
# Votes et abstention

# %%
import pandas as pd
import geopandas as gpd
import os 
import matplotlib.pyplot as plt

# %%
dir=os.getcwd()

# %% [markdown]
# Densite de population

# %%
dens=pd.read_csv(dir+'\\brut\\metropole-densites-de-population-par-commune.csv',sep=';')
dens=dens.rename(columns={'Code INSEE':'insee',"Densité d'habitants (hab/km2)" : 'densitehabkm2'})
dens=dens[['insee','densitehabkm2']]

# %%
dens.insee=dens.insee.astype(int)
dens.dtypes
# Out:
# insee              int32
# densitehabkm2    float64
# dtype: object

# %%
A=dens.sort_values('insee').sort_values('insee')

# %%
list(A.insee)
# Out:
# [77001,
#  77002,
#  77003,
#  77004,
#  77005,
#  77006,
#  77007,
#  77008,
#  77009,
#  77010,
#  77011,
#  77012,
#  77013,
#  77014,
#  77015,
#  77016,
#  77018,
#  77019,
#  77020,
#  77021,
#  77022,
#  77023,
#  77024,
#  77025,
#  77026,
#  77027,
#  77028,
#  77029,
#  77030,
#  77031,
#  77032,
#  77033,
#  77034,
#  77035,
#  77036,
#  77037,
#  77038,
#  77039,
#  77040,
#  77041,
#  77042,
#  77043,
#  77044,
#  77045,
#  77046,
#  77047,
#  77048,
#  77049,
#  77050,
#  77051,
#  77052,
#  77053,
#  77054,
#  77055,
#  77056,
#  77057,
#  77058,
#  77059,
#  77060,
#  77061,
#  77062,
#  77063,
#  77065,
#  77066,
#  77067,
#  77068,
#  77069,
#  77070,
#  77071,
#  77072,
#  77073,
#  77075,
#  77076,
#  77077,
#  77078,
#  77079,
#  77080,
#  77081,
#  77082,
#  77083,
#  77084,
#  77085,
#  77086,
#  77087,
#  77088,
#  77089,
#  77090,
#  77091,
#  77093,
#  77094,
#  77095,
#  77096,
#  77097,
#  77098,
#  77099,
#  77100,
#  77101,
#  77102,
#  77103,
#  77104,
#  77106,
#  77107,
#  77108,
#  77109,
#  77110,
#  77111,
#  77112,
#  77113,
#  77114,
#  77115,
#  77116,
#  77117,
#  77118,
#  77119,
#  77120,
#  77121,
#  77122,
#  77123,
#  77124,
#  77125,
#  77126,
#  77127,
#  77128,
#  77129,
#  77130,
#  77131,
#  77132,
#  77133,
#  77134,
#  77135,
#  77136,
#  77137,
#  77138,
#  77139,
#  77140,
#  77141,
#  77142,
#  77143,
#  77144,
#  77145,
#  77146,
#  77147,
#  77148,
#  77149,
#  77150,
#  77151,
#  77152,
#  77153,
#  77154,
#  77155,
#  77156,
#  77157,
#  77158,
#  77159,
#  77161,
#  77162,
#  77163,
#  77164,
#  77165,
#  77167,
#  77168,
#  77169,
#  77171,
#  77172,
#  77173,
#  77174,
#  77175,
#  77176,
#  77177,
#  77178,
#  77179,
#  77180,
#  77181,
#  77182,
#  77183,
#  77184,
#  77185,
#  77186,
#  77187,
#  77188,
#  77190,
#  77191,
#  77192,
#  77193,
#  77194,
#  77195,
#  77196,
#  77197,
#  77198,
#  77199,
#  77200,
#  77201,
#  77202,
#  77203,
#  77204,
#  77205,
#  77206,
#  77207,
#  77208,
#  77209,
#  77210,
#  78530,
#  78531,
#  78536,
#  78537,
#  78545,
#  78548,
#  78550,
#  78551,
#  78557,
#  78558,
#  78559,
#  78561,
#  78562,
#  78564,
#  78565,
#  78567,
#  78569,
#  78571,
#  78575,
#  78576,
#  78586,
#  78588,
#  78590,
#  78591,
#  78597,
#  78601,
#  78605,
#  78606,
#  78608,
#  78609,
#  78615,
#  78616,
#  78618,
#  78620,
#  78621,
#  78623,
#  78624,
#  78638,
#  78640,
#  78642,
#  78643,
#  78644,
#  78646,
#  78647,
#  78650,
#  78653,
#  78655,
#  78668,
#  78672,
#  78674,
#  78677,
#  78681,
#  78683,
#  78686,
#  78688,
#  91001,
#  91016,
#  91017,
#  91021,
#  91022,
#  91027,
#  91035,
#  91037,
#  91038,
#  91041,
#  91044,
#  91045,
#  91047,
#  91064,
#  91067,
#  91069,
#  91075,
#  91079,
#  91080,
#  91081,
#  91085,
#  91086,
#  91093,
#  91095,
#  91097,
#  91098,
#  91099,
#  91100,
#  91103,
#  91105,
#  91106,
#  91109,
#  91111,
#  91112,
#  91114,
#  91115,
#  91121,
#  91122,
#  91129,
#  91130,
#  91131,
#  91132,
#  91135,
#  91136,
#  91137,
#  91145,
#  91148,
#  91156,
#  91159,
#  91161,
#  91174,
#  91175,
#  91179,
#  91180,
#  91182,
#  91184,
#  91186,
#  91191,
#  91195,
#  91198,
#  91200,
#  91201,
#  91204,
#  91207,
#  91215,
#  91216,
#  91222,
#  91223,
#  91225,
#  91226,
#  91228,
#  91232,
#  91235,
#  91240,
#  91243,
#  91244,
#  91247,
#  91248,
#  91249,
#  91272,
#  91273,
#  91274,
#  91275,
#  91284,
#  91286,
#  91292,
#  91293,
#  91294,
#  91312,
#  91315,
#  91318,
#  91319,
#  91326,
#  91330,
#  91332,
#  91333,
#  91338,
#  91339,
#  91340,
#  91345,
#  91347,
#  91359,
#  91363,
#  91374,
#  91376,
#  91377,
#  91378,
#  91386,
#  91390,
#  91393,
#  91399,
#  91405,
#  91408,
#  91411,
#  91412,
#  91414,
#  91421,
#  91425,
#  91432,
#  91433,
#  91434,
#  91435,
#  91441,
#  91457,
#  91458,
#  91461,
#  91463,
#  91468,
#  91469,
#  91471,
#  91473,
#  91477,
#  91479,
#  91482,
#  91494,
#  91495,
#  91507,
#  91508,
#  91511,
#  91514,
#  91519,
#  91521,
#  91525,
#  91526,
#  91533,
#  91534,
#  91538,
#  91540,
#  91544,
#  91546,
#  91547,
#  91549,
#  91552,
#  91553,
#  91556,
#  91560,
#  91568,
#  91570,
#  91573,
#  91577,
#  91578,
#  91579,
#  91581,
#  91587,
#  91589,
#  91593,
#  91599,
#  91600,
#  91602,
#  91613,
#  91617,
#  91619,
#  91629,
#  91630,
#  91631,
#  91634,
#  91635,
#  91639,
#  91645,
#  91648,
#  91649,
#  91654,
#  91657,
#  91659,
#  91661,
#  91662,
#  91665,
#  91666,
#  91667,
#  91671,
#  91679,
#  91685,
#  91687,
#  91689,
#  91691,
#  91692,
#  92002,
#  92004,
#  92007,
#  92009,
#  92012,
#  92014,
#  92019,
#  92020,
#  92022,
#  92023,
#  92024,
#  92025,
#  92026,
#  92032,
#  92033,
#  92035,
#  92036,
#  92040,
#  92044,
#  92046,
#  92047,
#  92048,
#  92049,
#  92050,
#  92051,
#  92060,
#  92062,
#  92063,
#  92064,
#  92071,
#  92072,
#  ...]

# %% [markdown]
# Niveau de vie et taux de pauvreté

# %%
com=pd.read_csv(dir+'\\brut\\base-comparateur-de-territoires.csv',sep=';')
com=com.rename(columns={'CODGEO':'insee','MED16':'medianendv','TP6016':'tp'})
com=com[['insee','tp','medianendv']]

# %%
com.insee=com.insee.astype(int)
com.dtypes
# Out:
# insee           int32
# tp            float64
# medianendv    float64
# dtype: object

# %%
com.head() # tp on a pas pour tout
# Out:
#    insee    tp    medianendv
# 0  77006   NaN  26092.333333
# 1  77014  14.0  22116.500000
# 2  77018   8.0  24604.000000
# 3  77024   NaN  22022.222222
# 4  77038   NaN  29417.500000

# %%
len(com.insee.unique())
# Out:
# 1287

# %% [markdown]
# Pollution

# %%
pol=pd.read_csv(dir+'\\brut\\indices_QA_commune_IDF_2017.csv',sep=',')

pol=pol.groupby('ninsee',as_index=False).mean()

pol=pol.rename(columns={'ninsee':'insee'})

# %%
pol.insee=pol.insee.astype(int)

# %%
pol.dtypes
# Out:
# insee      int32
# no2      float64
# o3       float64
# pm10     float64
# dtype: object

# %% [markdown]
# Diplomes

# %%
dipl = pd.read_csv(dir+'\\brut\\base-cc-diplomes-formation-2016.csv',sep=';')
# Out:
# C:\Users\morga\AppData\Roaming\Python\Python37\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
dipl=dipl[['CODGEO','P16_NSCOL15P','P16_NSCOL15P_SUP']]

dipl=dipl.rename(columns={'P16_NSCOL15P':'nb_nscol','P16_NSCOL15P_SUP':'dipl_sup','CODGEO':'insee'})

dipl=dipl.assign(dipl_su_tx=dipl.dipl_sup/dipl.nb_nscol)

dipl=dipl[['insee','dipl_su_tx']]

# %%
dipl.dtypes
# Out:
# insee          object
# dipl_su_tx    float64
# dtype: object

# %%
import numpy as np

# %%
dipl=dipl[pd.to_numeric(dipl['insee'], errors='coerce').notnull()]

# %%
dipl.insee=dipl.insee.astype(int)

# %% [markdown]
# Prix au mètre carré

# %%
prix=pd.read_csv(dir+'\\brut\\prixm2-communes-2017.csv',sep=',')

prix=prix[['INSEE_COM','Prixm2']]

prix=prix.rename(columns={'INSEE_COM':'insee','Prixm2':'prixm2'})

# %%
prix.dtypes
# Out:
# insee      object
# prixm2    float64
# dtype: object

# %%
prix=prix[pd.to_numeric(prix['insee'], errors='coerce').notnull()]
prix.insee=prix.insee.astype(int)

# %%
prix.dtypes
# Out:
# insee       int32
# prixm2    float64
# dtype: object

# %% [markdown]
# Impôt sur la fortune

# %%
isf=pd.read_excel(dir+'\\brut\\ificom2018.xlsx',headers=True,sheet_name='définitif impot')

isf=isf[['Code commune (INSEE)','nombre de redevables','patrimoine moyen en €','impôt moyen en €']]

isf.columns=['insee','nb_redevables','patrimoineeuro','impotmoyeneuro']

# %%
isf.dtypes
# Out:
# insee              object
# nb_redevables       int64
# patrimoineeuro    float64
# impotmoyeneuro    float64
# dtype: object

# %%
isf['insee']= isf['insee'].transform(lambda x : x.replace(' ',''))

# %%
isf=isf[pd.to_numeric(isf['insee'], errors='coerce').notnull()]
isf.insee=isf.insee.astype(int)

# %%
isf.dtypes
# Out:
# insee               int32
# nb_redevables       int64
# patrimoineeuro    float64
# impotmoyeneuro    float64
# dtype: object

# %%
#Base Sarah 
eco=pd.read_csv(dir+'\\brut\\data_chom_prop.csv')
eco.head()
# Out:
#    Unnamed: 0  insee  TauxProprietaires  TauxChomage  NiveauVieMedian
# 0       29274  75056          33.097629    12.070128          26808.0
# 1       29983  77001          89.804772     7.377049          28596.0
# 2       29984  77002          82.445141     8.505155          22877.0
# 3       29985  77003          83.448276     5.238095          25606.0
# 4       29986  77004          90.082645     4.794521          26871.0

# %%
eco=eco.drop(columns=['Unnamed: 0'])
eco=eco.rename(columns={'CODGEO':'insee'})

# %%
eco.dtypes
# Out:
# insee                  int64
# TauxProprietaires    float64
# TauxChomage          float64
# NiveauVieMedian      float64
# dtype: object

# %% [markdown]
# Votes

# %%
#vote =pd.read_csv(dir+'\\brut\\data_final_vote.csv')
#vote=vote[['CODGEO','Tour1Candidat1']]

# %%
#vote=vote.rename(columns={'CODGEO':'insee'})

# %%
# Vote à la mano 
vote = pd.read_excel(dir+'\\brut\\vote_mano.xlsx')

# %% [markdown]
# Merge

# %%
bases=[eco,dens,dipl,pol,vote,com,isf,prix]

# %%
import geopandas as gpd 
pop=gpd.read_file(r'C:\Users\morga\Documents\GitHub\MLPython\dataviz\Graphique_bokeh\pop_comgeo.geojson')
variables= pd.DataFrame(pop.insee)
variables.insee=variables.insee.astype(int)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-c0287fb05d89> in <module>
#       1 import geopandas as gpd
# ----> 2 pop=gpd.read_file(r'C:\Users\morga\Documents\GitHub\MLPython\dataviz\Graphique_bokeh\pop_comgeo.geojson')
#       3 variables= pd.DataFrame(pop.insee)
#       4 variables.insee=variables.insee.astype(int)
#
# ~\Anaconda3\lib\site-packages\geopandas\io\file.py in read_file(filename, bbox, **kwargs)
#      93
#      94             columns = list(features.meta["schema"]["properties"]) + ["geometry"]
# ---> 95             gdf = GeoDataFrame.from_features(f_filt, crs=crs, columns=columns)
#      96
#      97     return gdf
#
# ~\Anaconda3\lib\site-packages\geopandas\geodataframe.py in from_features(cls, features, crs, columns)
#     281
#     282         rows = []
# --> 283         for f in features_lst:
#     284             if hasattr(f, "__geo_interface__"):
#     285                 f = f.__geo_interface__
#
# fiona/ogrext.pyx in fiona.ogrext.Iterator.__next__()
#
# fiona/ogrext.pyx in fiona.ogrext.FeatureBuilder.build()
#
# TypeError: startswith first arg must be bytes or a tuple of bytes, not str

# %%
pop.plot()

# %%
for data in bases:
    variables=variables.merge(data,how='left',on='insee')

# %%
variables.head()

# %%
# SOucis avec les élections j'ai pas les correspondances !!

# %%
variables.drop_duplicates( inplace = True)

# %%
#variables.drop('Unnamed: 0', axis=1, inplace=True)

# %%
variables = variables.round(2)

# %%
variables.to_csv('variables.csv')

# %% [markdown]
# Creation du CSV our la population slider

# %%
import geopandas as gpd 
pop=gpd.read_file(r'C:\Users\morga\Documents\GitHub\MLPython\dataviz\Graphique_bokeh\pop_comgeo.geojson')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-8c88aeb8d83d> in <module>
#       1 import geopandas as gpd
# ----> 2 pop=gpd.read_file(r'C:\Users\morga\Documents\GitHub\MLPython\dataviz\Graphique_bokeh\pop_comgeo.geojson')
#
# ~\Anaconda3\lib\site-packages\geopandas\io\file.py in read_file(filename, bbox, **kwargs)
#      93
#      94             columns = list(features.meta["schema"]["properties"]) + ["geometry"]
# ---> 95             gdf = GeoDataFrame.from_features(f_filt, crs=crs, columns=columns)
#      96
#      97     return gdf
#
# ~\Anaconda3\lib\site-packages\geopandas\geodataframe.py in from_features(cls, features, crs, columns)
#     281
#     282         rows = []
# --> 283         for f in features_lst:
#     284             if hasattr(f, "__geo_interface__"):
#     285                 f = f.__geo_interface__
#
# fiona/ogrext.pyx in fiona.ogrext.Iterator.__next__()
#
# fiona/ogrext.pyx in fiona.ogrext.FeatureBuilder.build()
#
# TypeError: startswith first arg must be bytes or a tuple of bytes, not str

# %%
pop=pop[['insee','year','population','pct_ch','steps']]

# %%
pop.to_csv('population_csv.csv')

# %%
pop[pop.insee=='78561']

# %% [markdown]
# Professionnels de Santé

# %%
med=pd.read_csv(dir+'\\brut\\annuaire-et-localisation-des-professionnels-de-sante.csv',sep=';')

med=med[["Nature de l'exercice","Convention du professionnel","Coordonnées",'Adresse','Code INSEE']]

med.columns=['nature_exercice','convention','coordonnees','adresse','insee']

# %%
# Ici interessant de mettre des marqueurs ? Je laisse comme ça => sinon compter 
count_med=med.groupby('insee',as_index=False)['coordonnees'].count()

# %%
med.dtypes
# Out:
# nature_exercice    object
# convention         object
# coordonnees        object
# adresse            object
# insee               int64
# dtype: object

# %%
count_med.dtypes
# Out:
# insee          int64
# coordonnees    int64
# dtype: object

# %%
med.insee=med.insee.astype(int)

# %%
med.columns
# Out:
# Index(['nature_exercice', 'convention', 'coordonnees', 'adresse', 'insee'], dtype='object')

# %%
med=med[['nature_exercice','coordonnees','insee']]

# %%
med=med.merge(count_med,on='insee')

# %%
med.columns=['nature','coordonnees','insee','nombre']

# %%
new= med["coordonnees"].str.split(",", n = 1, expand = True)

# %%
med_data['lat'] = new[0]
med_data['lon'] = new[1]

# %%
med_data
# Out:
#                          nature coordonnees  insee  nombre  \
# 0     Libéral activité salariée   48.970077  95197      32
# 1              Libéral intégral   48.970077  95197      32
# 2              Libéral intégral    48.96271  95197      32
# 3              Libéral intégral    48.96271  95197      32
# 4     Libéral activité salariée   48.971396  95197      32
# ...                         ...         ...    ...     ...
# 7773           Libéral intégral   49.014456  77241       4
# 7774           Libéral intégral   48.704353  91136       1
# 7775           Libéral intégral   49.064301  77322       2
# 7776           Libéral intégral   49.064414  77322       2
# 7777           Libéral intégral   49.050302  77259       1
#
#                                                geometry        new        lat  \
# 0     POLYGON ((2.30969 48.97072, 2.30979 48.97119, ...  48.970077  48.829281
# 1     POLYGON ((2.30969 48.97072, 2.30979 48.97119, ...  48.970077  48.824815
# 2     POLYGON ((2.30969 48.97072, 2.30979 48.97119, ...   48.96271  48.883061
# 3     POLYGON ((2.30969 48.97072, 2.30979 48.97119, ...   48.96271  48.833789
# 4     POLYGON ((2.30969 48.97072, 2.30979 48.97119, ...  48.971396  48.853281
# ...                                                 ...        ...        ...
# 7773  POLYGON ((2.67922 49.01336, 2.68390 49.01933, ...  49.014456  48.857847
# 7774  POLYGON ((2.25880 48.70794, 2.25881 48.70836, ...  48.704353  48.854348
# 7775  POLYGON ((2.57098 49.06058, 2.57141 49.06093, ...  49.064301  48.844213
# 7776  POLYGON ((2.57098 49.06058, 2.57141 49.06093, ...  49.064414  48.865643
# 7777  POLYGON ((2.64263 49.04490, 2.64272 49.04625, ...  49.050302  48.851257
#
#            lon
# 0       2.3568
# 1     2.357629
# 2     2.329228
# 3     2.308108
# 4     2.293727
# ...        ...
# 7773  2.304228
# 7774  2.383557
# 7775  2.342242
# 7776  2.288865
# 7777  2.319338
#
# [7778 rows x 8 columns]

# %%
def df_to_geojson(df, properties, lat='lat', lon='lon'):
    geojson = {'type':'FeatureCollection', 'features':[]}
    for _, row in df.iterrows():
        feature = {'type':'Feature',
                   'properties':{},
                   'geometry':{'type':'Point',
                               'coordinates':[]}}
        feature['geometry']['coordinates'] = [row[lon],row[lat]]
        for prop in properties:
            feature['properties'][prop] = row[prop]
        geojson['features'].append(feature)
    return geojson

# %%
cols = ['insee','nombre','nature']
geojson = df_to_geojson(med_data, cols)

# %%
import json

with open('med_data.geojson', 'a') as f:
    json.dump(geojson, f)

# %%
#med_data.to_csv('med_data.csv')

# %%
med_data["coordonnees"]= med_data["coordonnees"].str.split(",", n = 2, expand = True)

# %%
med_data
# Out:
#                          nature coordonnees  insee  nombre  \
# 0     Libéral activité salariée   48.970077  95197      32
# 1              Libéral intégral   48.970077  95197      32
# 2              Libéral intégral    48.96271  95197      32
# 3              Libéral intégral    48.96271  95197      32
# 4     Libéral activité salariée   48.971396  95197      32
# ...                         ...         ...    ...     ...
# 7773           Libéral intégral   49.014456  77241       4
# 7774           Libéral intégral   48.704353  91136       1
# 7775           Libéral intégral   49.064301  77322       2
# 7776           Libéral intégral   49.064414  77322       2
# 7777           Libéral intégral   49.050302  77259       1
#
#                                                geometry
# 0     POLYGON ((2.30969 48.97072, 2.30979 48.97119, ...
# 1     POLYGON ((2.30969 48.97072, 2.30979 48.97119, ...
# 2     POLYGON ((2.30969 48.97072, 2.30979 48.97119, ...
# 3     POLYGON ((2.30969 48.97072, 2.30979 48.97119, ...
# 4     POLYGON ((2.30969 48.97072, 2.30979 48.97119, ...
# ...                                                 ...
# 7773  POLYGON ((2.67922 49.01336, 2.68390 49.01933, ...
# 7774  POLYGON ((2.25880 48.70794, 2.25881 48.70836, ...
# 7775  POLYGON ((2.57098 49.06058, 2.57141 49.06093, ...
# 7776  POLYGON ((2.57098 49.06058, 2.57141 49.06093, ...
# 7777  POLYGON ((2.64263 49.04490, 2.64272 49.04625, ...
#
# [7778 rows x 5 columns]

# %%
import geopandas as gpd 
pop=gpd.read_file(r'C:\Users\morga\Documents\GitHub\MLPython\dataviz\Graphique_bokeh\pop_comgeo.geojson')

# %%
pop=pop[['insee','geometry']]

# %%
pop=pop.drop_duplicates()

# %%
pop.insee=pop.insee.astype(int)

# %%
med_merge=med_data[['nature','nombre','insee']]

# %%
med_merge = med_merge.merge(pop)

# %%
med_merge.columns
# Out:
# Index(['nature', 'nombre', 'insee', 'geometry'], dtype='object')

# %%
from geopandas import GeoDataFrame
med_merge = GeoDataFrame(med_merge, geometry=med_merge['geometry'])

# %%
med_merge.to_file("med_merge.geojson", driver='GeoJSON')

# %%
med_merge=med_merge[['insee','nombre','geometry']]

# %%
med_merge.nombre.max()
# Out:
# 393

# %% [markdown]
# # Traffic (lié aux stations et non aux communes)

# %%
traffic=pd.read_csv(r'C:/Users/morga/Downloads/validations-sur-le-reseau-ferre-nombre-de-validations-par-jour-2e-sem.csv',sep=';')

# %%
pd.options.display.max_rows = 999

# %%
traffic[traffic['LIBELLE_ARRET']=='GARE DU NORD'].head(100)
# Out:
#              JOUR  CODE_STIF_TRNS  CODE_STIF_RES  CODE_STIF_ARRET  \
# 320    2018-11-13             100          110.0            318.0
# 2018   2018-11-13             800          853.0            308.0
# 2357   2018-11-20             800          853.0            308.0
# 2359   2018-11-20             800          853.0            308.0
# 2360   2018-11-20             800          853.0            308.0
# 2632   2018-11-12             800          853.0            308.0
# 15499  GARE DU NORD       71410          NAVIGO  45520.0
# 16468  GARE DU NORD       71410     AUTRE TITRE    471.0
# 16470  GARE DU NORD       71410             FGT    808.0
# 16472  GARE DU NORD       71410       IMAGINE R   1519.0
# 16474  GARE DU NORD       71410          NAVIGO  13916.0
# 16684  GARE DU NORD       71410               ?     55.0
# 16686  GARE DU NORD       71410       AMETHYSTE   1095.0
# 16688  GARE DU NORD       71410             TST   6659.0
# 16847  GARE DU NORD       71410       AMETHYSTE   1151.0
# 16848  GARE DU NORD       71410     AUTRE TITRE   4056.0
# 17622  GARE DU NORD       71410       IMAGINE R   4186.0
# 17708  GARE DU NORD       71410     AUTRE TITRE    600.0
# 18143  GARE DU NORD       71410               ?      5.0
# 18360  GARE DU NORD       71410          NAVIGO  51126.0
# 19060  GARE DU NORD       71410          NAVIGO  42584.0
# 20323  GARE DU NORD       71410               ?     35.0
# 20324  GARE DU NORD       71410             FGT   3408.0
# 20988  GARE DU NORD       71410       AMETHYSTE   1296.0
# 21780  GARE DU NORD       71410          NAVIGO   3361.0
# 23005  GARE DU NORD       71410     AUTRE TITRE    311.0
# 23007  GARE DU NORD       71410             FGT    776.0
# 23009  GARE DU NORD       71410          NAVIGO   8473.0
# 24186  GARE DU NORD       71410       AMETHYSTE   1323.0
# 24189  GARE DU NORD       71410          NAVIGO  24948.0
# 24703  GARE DU NORD       71410       AMETHYSTE    889.0
# 24704  GARE DU NORD       71410          NAVIGO  20836.0
# 25593  GARE DU NORD       71410       IMAGINE R   1608.0
# 25595  GARE DU NORD       71410      NON DEFINI      NaN
# 26726  GARE DU NORD       71410       IMAGINE R   4515.0
# 27492  GARE DU NORD       71410               ?     38.0
# 27494  GARE DU NORD       71410     AUTRE TITRE   5623.0
# 28269  GARE DU NORD       71410             FGT    645.0
# 28504  GARE DU NORD       71410               ?     46.0
# 28506  GARE DU NORD       71410             FGT   3282.0
# 29029  GARE DU NORD       71410          NAVIGO   7633.0
# 29404  GARE DU NORD       71410               ?     37.0
# 29543  GARE DU NORD       71410     AUTRE TITRE   4151.0
# 29545  GARE DU NORD       71410          NAVIGO  49286.0
# 29548  GARE DU NORD       71410             TST   6356.0
# 30369  GARE DU NORD       71410               ?     13.0
# 30372  GARE DU NORD       71410       AMETHYSTE    451.0
# 30375  GARE DU NORD       71410          NAVIGO  17448.0
# 30508  GARE DU NORD       71410             FGT   2434.0
# 30509  GARE DU NORD       71410       IMAGINE R   3081.0
# 30926  GARE DU NORD       71410       AMETHYSTE    357.0
# 30928  GARE DU NORD       71410     AUTRE TITRE    421.0
# 30930  GARE DU NORD       71410             FGT    610.0
# 31442  GARE DU NORD       71410       IMAGINE R   1484.0
# 32403  GARE DU NORD       71410             FGT    725.0
# 32947  GARE DU NORD       71410               ?     27.0
# 32952  GARE DU NORD       71410       AMETHYSTE   1281.0
# 32956  GARE DU NORD       71410     AUTRE TITRE   4808.0
# 33265  GARE DU NORD       71410          NAVIGO  38609.0
# 34926  GARE DU NORD       71410             TST   1107.0
# 34949  GARE DU NORD       71410               ?     15.0
# 34954  GARE DU NORD       71410       AMETHYSTE    342.0
# 34958  GARE DU NORD       71410       IMAGINE R   1464.0
# 34961  GARE DU NORD       71410          NAVIGO  13030.0
# 34964  GARE DU NORD       71410             TST   1234.0
# 35981  GARE DU NORD       71410          NAVIGO  11571.0
# 35982  GARE DU NORD       71410             TST   1278.0
# 37233  GARE DU NORD       71410       AMETHYSTE   1449.0
# 37236  GARE DU NORD       71410          NAVIGO  52188.0
# 37792  GARE DU NORD       71410     AUTRE TITRE   3886.0
# 37810  GARE DU NORD       71410          NAVIGO  11788.0

# %%
traffic.groupby(['JOUR'],as_index=False).mean()
# Out:
#            JOUR  CODE_STIF_TRNS  CODE_STIF_RES  CODE_STIF_ARRET      NB_VALD
# 0    2018-07-01      487.476232     503.792208       485.398268   503.142292
# 1    2018-07-02      503.555055     521.127921       484.228987  1216.861603
# 2    2018-07-03      504.064622     521.583591       483.714698  1323.580691
# 3    2018-07-04      503.149917     520.715474       482.895799  1333.968861
# 4    2018-07-05      504.750051     522.499897       483.653822  1341.385650
# ..          ...             ...            ...              ...          ...
# 179  2018-12-27      493.062072     510.388854       482.142441   837.527874
# 180  2018-12-28      494.290622     511.450810       482.023077   879.479546
# 181  2018-12-29      487.996709     505.002060       480.192419   606.129288
# 182  2018-12-30      482.869348     499.573575       480.626383   473.238824
# 183  2018-12-31      491.605617     508.619038       483.613942   468.403933
#
# [184 rows x 5 columns]

# %%
traffic=traffic[traffic['CODE_STIF_TRNS']==810]

CHAT = traffic[traffic['LIBELLE_ARRET'].str.startswith('CHAT')]

traffic=traffic[traffic['CODE_STIF_RES']==802]

traffic=traffic.append(CHAT)

traffic=traffic.groupby(['JOUR','LIBELLE_ARRET'],as_index=False)['NB_VALD'].sum()

traffic=traffic[['LIBELLE_ARRET','NB_VALD']]

traffic=traffic.groupby(['LIBELLE_ARRET'],as_index=False).mean()

# %%
liste_stations = list(traffic.LIBELLE_ARRET.unique()) + ['GARE DU NORD']

# %%
traffic=pd.read_csv(dir + 'brut\\validations-sur-le-reseau-ferre-nombre-de-validations-par-jour-2e-sem.csv',sep=';')

# %%
traffic=traffic[traffic['LIBELLE_ARRET'].isin(liste_stations)]

# %%
traffic=traffic.groupby(['JOUR','LIBELLE_ARRET'],as_index=False)['NB_VALD'].sum()

traffic=traffic[['LIBELLE_ARRET','NB_VALD']]

traffic=traffic.groupby(['LIBELLE_ARRET'],as_index=False).mean()

# %%
traffic
# Out:
#                        LIBELLE_ARRET       NB_VALD
# 0       AEROPORT CHARLES DE GAULLE 1   4751.359551
# 1   AEROPORT CHARLES DE GAULLE 2-TGV   6158.989071
# 2                             ANTONY  11292.179348
# 3                     ARCUEIL-CACHAN   8561.918478
# 4                   AULNAY-SOUS-BOIS  15838.554348
# 5                            BAGNEUX   5624.396739
# 6                       BLANC-MESNIL   3551.989011
# 7                     BOURG-LA-REINE  10464.875000
# 8                   BURES-SUR-YVETTE   1350.456522
# 9                CHATELET-LES HALLES  54721.494565
# 10                    CHATOU-CROISSY   5186.755435
# 11                CITE UNIVERSITAIRE  16885.853261
# 12              COURCELLE-SUR-YVETTE    567.214286
# 13                 DENFERT-ROCHEREAU  17593.385870
# 14                            DRANCY   7047.913043
# 15                 FONTAINE-MICHALON   1617.548913
# 16                FONTENAY-AUX-ROSES   2661.152174
# 17                      GARE DU NORD  76449.326087
# 18                          GENTILLY   5464.619565
# 19                    GIF-SUR-YVETTE   1359.266304
# 20        LA COURNEUVE-AUBERVILLIERS  11722.668478
# 21         LA CROIX-DE-BERNY-FRESNES   7856.554348
# 22                    LA HACQUINIERE    572.635870
# 23         LA PLAINE-STADE DE FRANCE  14532.706522
# 24                           LAPLACE   8434.119565
# 25                        LE BOURGET  10666.902174
# 26                        LE GUICHET   1695.706522
# 27                     LES BACONNETS   4432.175824
# 28                            LOZERE   1151.967391
# 29                        LUXEMBOURG  12565.005435
# 30                   MASSY-PALAISEAU  22462.826087
# 31                   MASSY-VERRIERES   1234.048913
# 32                       MITRY-CLAYE   2424.347826
# 33                       ORSAY-VILLE   3428.869565
# 34                         PALAISEAU   1579.603261
# 35                PALAISEAU-VILLEBON   1441.521739
# 36              PARC DES EXPOSITIONS   3891.549451
# 37                    PARC-DE-SCEAUX   1289.239130
# 38                        PORT ROYAL   7467.168478
# 39                          ROBINSON   4981.239130
# 40           SAINT-MICHEL NOTRE DAME  18866.548913
# 41          SAINT-REMY-LES-CHEVREUSE   1296.581921
# 42                            SCEAUX   1589.190217
# 43                 SEVRAN-BEAUDOTTES   8467.601124
# 44                      SEVRAN-LIVRY   4117.109290
# 45                       VERT-GALANT   5518.695652
# 46        VILLEPARISIS-MITRY-LE-NEUF   2825.579235
# 47                        VILLEPINTE   2540.784530

# %%
perc_traffic=pd.read_csv(dir +'\\brut\\validations-sur-le-reseau-ferre-profils-horaires-par-jour-type-2e-sem.csv',sep=';')

# %%
perc_traffic=perc_traffic[perc_traffic['LIBELLE_ARRET'].isin(liste_stations)]

# %%
perc_traffic=perc_traffic[perc_traffic['CAT_JOUR']=='JOHV']

# %%
perc_traffic=perc_traffic[['LIBELLE_ARRET','pourc_validations','TRNC_HORR_60']]

# %%
perc_traffic=perc_traffic.groupby(['LIBELLE_ARRET','TRNC_HORR_60'],as_index=False)['pourc_validations'].mean()

# %%
traffic_par_heure=perc_traffic.merge(traffic,how='left')

# %%
traffic_par_heure=traffic_par_heure.assign(NB_VALD_HOUR=traffic_par_heure.pourc_validations*traffic_par_heure.NB_VALD)

# %%
traffic_par_heure.to_csv('traffic_par_heure.csv')

# %%
traffic_par_heure=pd.read_csv('traffic_par_heure.csv')

# %%
list(traffic_par_heure.LIBELLE_ARRET.unique())
# Out:
# ['AEROPORT CHARLES DE GAULLE 1',
#  'AEROPORT CHARLES DE GAULLE 2-TGV',
#  'ANTONY',
#  'ARCUEIL-CACHAN',
#  'AULNAY-SOUS-BOIS',
#  'BAGNEUX',
#  'BLANC-MESNIL',
#  'BOURG-LA-REINE',
#  'BURES-SUR-YVETTE',
#  'CHATELET-LES HALLES',
#  'CHATOU-CROISSY',
#  'CITE UNIVERSITAIRE',
#  'COURCELLE-SUR-YVETTE',
#  'DENFERT-ROCHEREAU',
#  'DRANCY',
#  'FONTAINE-MICHALON',
#  'FONTENAY-AUX-ROSES',
#  'GARE DU NORD',
#  'GENTILLY',
#  'GIF-SUR-YVETTE',
#  'LA COURNEUVE-AUBERVILLIERS',
#  'LA CROIX-DE-BERNY-FRESNES',
#  'LA HACQUINIERE',
#  'LA PLAINE-STADE DE FRANCE',
#  'LAPLACE',
#  'LE BOURGET',
#  'LE GUICHET',
#  'LES BACONNETS',
#  'LOZERE',
#  'LUXEMBOURG',
#  'MASSY-PALAISEAU',
#  'MASSY-VERRIERES',
#  'MITRY-CLAYE',
#  'ORSAY-VILLE',
#  'PALAISEAU',
#  'PALAISEAU-VILLEBON',
#  'PARC DES EXPOSITIONS',
#  'PARC-DE-SCEAUX',
#  'PORT ROYAL',
#  'ROBINSON',
#  'SAINT-MICHEL NOTRE DAME',
#  'SAINT-REMY-LES-CHEVREUSE',
#  'SCEAUX',
#  'SEVRAN-BEAUDOTTES',
#  'SEVRAN-LIVRY',
#  'VERT-GALANT',
#  'VILLEPARISIS-MITRY-LE-NEUF',
#  'VILLEPINTE']

# %%
traffic_par_heure['LIBELLE_ARRET']= traffic_par_heure['LIBELLE_ARRET'].str.replace('SAINT-MICHEL NOTRE DAME', 'SAINT-MICHEL', regex=True)

# %%
traffic_par_heure.to_csv('traffic_par_heure.csv')

# %%
import geopandas as gpd 
stations=gpd.read_file(r'C:\Users\morga\Documents\GitHub\MLPython\dataviz\Graphique_bokeh\stations.geojson')

# %%
list(stations.nom_long.unique())
# Out:
# ['MASSY-PALAISEAU',
#  'SAINT-REMY-LES-CHEVREUSE',
#  'GIF-SUR-YVETTE',
#  'BURES-SUR-YVETTE',
#  'PORT ROYAL',
#  'LA CROIX-DE-BERNY-FRESNES',
#  'GENTILLY',
#  'LAPLACE',
#  'LA HACQUINIERE',
#  'BOURG-LA-REINE',
#  'PARC-DE-SCEAUX',
#  'BAGNEUX',
#  'MASSY-VERRIERES',
#  'FONTAINE-MICHALON',
#  'LES BACONNETS',
#  'PALAISEAU-VILLEBON',
#  'LOZERE',
#  'ARCUEIL-CACHAN',
#  'ANTONY',
#  'ORSAY-VILLE',
#  'PALAISEAU',
#  'LE GUICHET',
#  'COURCELLE-SUR-YVETTE',
#  'DENFERT-ROCHEREAU',
#  'CITE UNIVERSITAIRE',
#  'SAINT-MICHEL',
#  'LUXEMBOURG',
#  'CHATELET-LES HALLES',
#  'LA PLAINE-STADE DE FRANCE',
#  'DRANCY',
#  'BLANC-MESNIL',
#  'PARC DES EXPOSITIONS',
#  'ROBINSON',
#  'SCEAUX',
#  'GARE DU NORD',
#  'MITRY-CLAYE',
#  'VILLEPARISIS-MITRY-LE-NEUF',
#  'LA COURNEUVE-AUBERVILLIERS',
#  'VERT-GALANT',
#  'AEROPORT CHARLES DE GAULLE 2-TGV',
#  'AULNAY-SOUS-BOIS',
#  'FONTENAY-AUX-ROSES',
#  'AEROPORT CHARLES DE GAULLE 1',
#  'LE BOURGET',
#  'SEVRAN-BEAUDOTTES',
#  'VILLEPINTE',
#  'SEVRAN-LIVRY']

# %%
stations=stations.merge(traffic_par_heure,left_on='nom_long',right_on='LIBELLE_ARRET',how='right')

# %%
stations=stations[stations['year']==2017]

# %%
stations=stations[['LIBELLE_ARRET','TRNC_HORR_60','NB_VALD_HOUR','pourc_validations','geometry']]

# %%
stations=stations.dropna()

# %%
stations=stations.drop_duplicates()

# %%
stations
# Out:
#         LIBELLE_ARRET TRNC_HORR_60  NB_VALD_HOUR  pourc_validations  \
# 8     MASSY-PALAISEAU        0H-1H   2470.910870              0.110
# 17    MASSY-PALAISEAU      10H-11H  65479.138043              2.915
# 26    MASSY-PALAISEAU      11H-12H  63345.169565              2.820
# 35    MASSY-PALAISEAU      12H-13H  76148.980435              3.390
# 44    MASSY-PALAISEAU      13H-14H  80753.859783              3.595
# ...               ...          ...           ...                ...
# 7913     SEVRAN-LIVRY        5H-6H  49446.482568             12.010
# 7918     SEVRAN-LIVRY        6H-7H  59039.347213             14.340
# 7923     SEVRAN-LIVRY        7H-8H  51463.866120             12.500
# 7928     SEVRAN-LIVRY        8H-9H  44588.293607             10.830
# 7933     SEVRAN-LIVRY       9H-10H  21244.283934              5.160
#
#                       geometry
# 8     POINT (2.25828 48.72469)
# 17    POINT (2.25828 48.72469)
# 26    POINT (2.25828 48.72469)
# 35    POINT (2.25828 48.72469)
# 44    POINT (2.25828 48.72469)
# ...                        ...
# 7913  POINT (2.53471 48.93628)
# 7918  POINT (2.53471 48.93628)
# 7923  POINT (2.53471 48.93628)
# 7928  POINT (2.53471 48.93628)
# 7933  POINT (2.53471 48.93628)
#
# [1102 rows x 5 columns]

# %%
new=stations.TRNC_HORR_60.str.split("H", n = 1, expand = True)

# %%
stations['heure']=new[0]

# %%
stations=stations[['LIBELLE_ARRET','NB_VALD_HOUR','pourc_validations','heure','geometry']]

# %%
stations
# Out:
#         LIBELLE_ARRET  NB_VALD_HOUR  pourc_validations heure  \
# 8     MASSY-PALAISEAU   2470.910870              0.110     0
# 17    MASSY-PALAISEAU  65479.138043              2.915    10
# 26    MASSY-PALAISEAU  63345.169565              2.820    11
# 35    MASSY-PALAISEAU  76148.980435              3.390    12
# 44    MASSY-PALAISEAU  80753.859783              3.595    13
# ...               ...           ...                ...   ...
# 7913     SEVRAN-LIVRY  49446.482568             12.010     5
# 7918     SEVRAN-LIVRY  59039.347213             14.340     6
# 7923     SEVRAN-LIVRY  51463.866120             12.500     7
# 7928     SEVRAN-LIVRY  44588.293607             10.830     8
# 7933     SEVRAN-LIVRY  21244.283934              5.160     9
#
#                       geometry
# 8     POINT (2.25828 48.72469)
# 17    POINT (2.25828 48.72469)
# 26    POINT (2.25828 48.72469)
# 35    POINT (2.25828 48.72469)
# 44    POINT (2.25828 48.72469)
# ...                        ...
# 7913  POINT (2.53471 48.93628)
# 7918  POINT (2.53471 48.93628)
# 7923  POINT (2.53471 48.93628)
# 7928  POINT (2.53471 48.93628)
# 7933  POINT (2.53471 48.93628)
#
# [1102 rows x 5 columns]

# %%
stations['heure']=stations.heure.astype(int)
# Out:
# C:\Users\morga\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
for i in list(stations.heure.unique()):
    stations_heure=stations[stations['heure']==i]
    stations_heure.to_file("stations"+str(i)+".geojson", driver='GeoJSON')

# %%
stations10[stations10['LIBELLE_ARRET']=='GARE DU NORD']
# Out:
#      LIBELLE_ARRET  NB_VALD_HOUR  pourc_validations  heure  \
# 6393  GARE DU NORD  272924.09413               3.57     10
#
#                       geometry
# 6393  POINT (2.35633 48.88092)

# %%
stations5[stations5['LIBELLE_ARRET']=='GARE DU NORD']
# Out:
#      LIBELLE_ARRET   NB_VALD_HOUR  pourc_validations  heure  \
# 6483  GARE DU NORD  239668.637283              3.135      5
#
#                       geometry
# 6483  POINT (2.35633 48.88092)

# %% [markdown]
# Cartes pour visualiser le résultat

# %%
import geopandas as gpd 
pop=gpd.read_file(r'C:\Users\morga\Documents\GitHub\MLPython\dataviz\Graphique_bokeh\pop_comgeo.geojson',encoding='utf-8')
pop.insee=pop.insee.astype(int)
data_map=variables.merge(pop,on='insee')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-b893f3380a6d> in <module>
#       1 import geopandas as gpd
# ----> 2 pop=gpd.read_file(r'C:\Users\morga\Documents\GitHub\MLPython\dataviz\Graphique_bokeh\pop_comgeo.geojson',encoding='utf-8')
#       3 pop.insee=pop.insee.astype(int)
#       4 data_map=variables.merge(pop,on='insee')
#
# ~\Anaconda3\lib\site-packages\geopandas\io\file.py in read_file(filename, bbox, **kwargs)
#      93
#      94             columns = list(features.meta["schema"]["properties"]) + ["geometry"]
# ---> 95             gdf = GeoDataFrame.from_features(f_filt, crs=crs, columns=columns)
#      96
#      97     return gdf
#
# ~\Anaconda3\lib\site-packages\geopandas\geodataframe.py in from_features(cls, features, crs, columns)
#     281
#     282         rows = []
# --> 283         for f in features_lst:
#     284             if hasattr(f, "__geo_interface__"):
#     285                 f = f.__geo_interface__
#
# fiona/ogrext.pyx in fiona.ogrext.Iterator.__next__()
#
# fiona/ogrext.pyx in fiona.ogrext.FeatureBuilder.build()
#
# TypeError: startswith first arg must be bytes or a tuple of bytes, not str

# %%
data_map.columns

# %%
import mapclassify
import geoplot
import matplotlib.pyplot as plt 
data_map=data_map.set_geometry('geometry')

# %%
scheme = mapclassify.Quantiles(data_map.TauxChomage, k=10)
geoplot.choropleth(
    data_map, hue=data_map.TauxChomage, scheme=scheme,
    cmap='OrRd', figsize=(10, 5),legend=True
)
plt.title('Taux de chômage')

# %%
scheme = mapclassify.Quantiles(data_map.TauxProprietaires, k=10)
geoplot.choropleth(
    data_map, hue=data_map.TauxProprietaires, scheme=scheme,
    cmap='OrRd', figsize=(10, 5),legend=True
)
plt.title('Taux de propriétaires')

# %%
scheme = mapclassify.Quantiles(data_map.pm10, k=10)
geoplot.choropleth(
    data_map, hue=data_map.pm10, scheme=scheme,
    cmap='OrRd', figsize=(10, 5),legend=True
)
plt.title('Taux pollution pm10')

# %%
scheme = mapclassify.Quantiles(data_map.dipl_su_tx, k=10)
geoplot.choropleth(
    data_map, hue=data_map.dipl_su_tx, scheme=scheme,
    cmap='OrRd', figsize=(10, 5),legend=True
)
plt.title('dipl_su_tx')

# %%
geoplot.choropleth(
    data_map, hue=data_map.Tour1Candidat1,
    cmap='OrRd', figsize=(10, 5),legend=True
)
plt.title('vote_politique')
